# %%
import requests
import pymysql
import json
from bs4 import BeautifulSoup


url="https://www.cwb.gov.tw/Data/js/week/ChartData_Week_County_C.js?T=2021110209-0&_=1635815086433"
headers={
        'user-agent':"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/95.0.4638.54 Safari/537.36"
        }#自定義直(網頁的headers
Cookies={'over18':'1',}#自定義直(網頁的Cookies

page=requests.get(url,headers=headers,cookies=Cookies)#帶入自定義直
doc = page.text

print(doc)
# Out:
# // Updated: 2021/11/02 06:23:40
#
# var Time_Week = ['11/02<br>(二)<br>白天','11/02<br>(二)<br>晚上','11/03<br>(三)<br>白天','11/03<br>(三)<br>晚上','11/04<br>(四)<br>白天','11/04<br>(四)<br>晚上','11/05<br>(五)<br>白天','11/05<br>(五)<br>晚上','11/06<br><span style="color:#ea1904;">(六)</span><br>白天','11/06<br><span style="color:#ea1904;">(六)</span><br>晚上','11/07<br><span style="color:#ea1904;">(日)</span><br>白天','11/07<br><span style="color:#ea1904;">(日)</span><br>晚上','11/08<br>(一)<br>白天','11/08<br>(一)<br>晚上'];
#
# var TempArray_Week = {
#     '10017':{'C':{'H':[23,22,23,22,23,22,26,23,23,22,23,21,20,15],'L':[21,21,21,20,20,21,21,21,21,21,21,20,15,14]},'F':{'H':[73,72,73,72,73,72,79,73,73,72,73,70,68,59],'L':[70,70,70,68,68,70,70,70,70,70,70,68,59,57]},
#         'Wx':[['07','陰天'],['11','陰短暫雨'],['11','陰短暫雨'],['11','陰短暫雨'],['11','陰短暫陣雨'],['08','多雲短暫陣雨'],['08','多雲短暫陣雨'],['04','多雲'],['08','多雲短暫陣雨'],['08','多雲短暫陣雨'],['04','多雲'],['09','多雲時陰短暫陣雨'],['11','陰短暫雨'],['11','陰短暫雨']]},
# ...

# %%
import re
patten = r"(^.*區)"
text = "台中市太平區還中東路132號 台中市東區中三路999號"
x =re.findall(patten,text,flags=re.M)#用geoup找text裏的字
print(x)
# Out:
# ['台中市太平區還中東路132號 台中市東區']
